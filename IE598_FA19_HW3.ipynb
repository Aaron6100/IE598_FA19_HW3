# %%
print("My name is Qianyi Liu")
print("My NetID is: qianyil2")
print("I hereby certify that I have read the University policy on Academic Integrity and that I am not in violation.")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#getting the data downloaded from compass2g.
#tried to use the url-extraction showed on the textbook, but found out that only part of the data was shown
#adjustment on that method needs to be done but not now
#I need to finish the assignment ASAP
#I guess I should use pandas to read eventually
df=pd.read_csv('/Users/fyxit/Desktop/HW3data.csv')
#getting info for the dataset
print('# of rows of data: ', df.shape[0])
print('# of columns of data: ', df.shape[1])
# Out:
# My name is Qianyi Liu
# My NetID is: qianyil2
# I hereby certify that I have read the University policy on Academic Integrity and that I am not in violation.
# # of rows of data:  2721
# # of columns of data:  37

# %%
#getting info for the dataset as well
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2721 entries, 0 to 2720
# Data columns (total 37 columns):
# CUSIP                         2721 non-null object
# Ticker                        2721 non-null object
# Issue Date                    2721 non-null object
# Maturity                      2721 non-null object
# 1st Call Date                 2721 non-null object
# Moodys                        2721 non-null object
# S_and_P                       2721 non-null object
# Fitch                         2721 non-null object
# Bloomberg Composite Rating    2721 non-null object
# Coupon                        2721 non-null float64
# Issued Amount                 2721 non-null float64
# Maturity Type                 2721 non-null object
# Coupon Type                   2721 non-null object
# Maturity At Issue months      2721 non-null float64
# Industry                      2721 non-null object
# LiquidityScore                2721 non-null float64
# ...

# %%
#---------Histogram--------
sns.set()
_= plt.hist(df["n_trades"], bins=5)
_= plt.xlabel('n_trades')
_= plt.ylabel('Number')
plt.show()

# %%
#----------- Q-Q Plot ------------
#I am selecting n_trades to be the model just because I guess it looks better
from scipy import stats
stats.probplot(df.n_trades, dist="norm", plot=plt)
plt.show()

# %%
# ---------- Parallel Coordinates Plots -------------
from pandas.plotting import parallel_coordinates
features = df[['Issue Date', 'Maturity', 'n_trades']][:20]

parallel_coordinates(features, 'n_trades')
plt.legend(loc='upper center', bbox_to_anchor=(0.5,-0.1),ncol=2,fancybox=True,shadow=True)
plt.show()

# %%
# -----------Scatter Plot--------------
d_1 = df.iloc[:100, 9]
d_2 = df.iloc[:100, 13]

plt.xlabel('Coupon')
plt.ylabel('Maturity')
plt.scatter(d_1, d_2)
plt.show()

# %%
# -----------Heat map--------------
new_data = pd.DataFrame(df.corr())
#corr means it needs to find the correlation of two columns
plt.pcolor(new_data)
plt.show()

# %%
#--------Swarm Plot----------
# well, I tried to use Coupon as the selected figure for this part but it seems
# that my laptop is taking forever to generate a plot, after 1000 years waiting
# I decided to use LIQ SCORE for now and get a new laptop in the future
_= sns.swarmplot('Months in Both','LIQ SCORE',data=df)
plt.show()

# %%
#-----------ECDF(datacamp)-----------
x = np.sort(df["LIQ SCORE"])
y = np.arange(1, len(x)+1) / len(x) 
plt.plot(x, y, marker='.', linestyle='none')
plt.xlabel("LIQ SCORE")
plt.ylabel("ECDF")
plt.show()

# %%
#---------BoxPlot-------
sns.set()
sns.boxplot(df["Moodys"][:40], df["Coupon"][:30], data=df)
plt.show()
